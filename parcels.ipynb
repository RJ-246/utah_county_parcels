# %%
import geopandas as gpd
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
ut_county = gpd.read_file("TaxParcels.gdb")

# %%
ut_county.plot(figsize=(8,8))

# %%
ut_county

# %%
orem_parcels = ut_county[ut_county["SITE_CITY"] == "OREM"]

# %%
orem_parcels

# %%
orem_parcels["ACCOUNT_TYPE"].unique()

# %%
orem_residential = orem_parcels[orem_parcels["ACCOUNT_TYPE"] == "RESIDENTIAL"]
orem_residential

# %%
orem_residential.explore()
